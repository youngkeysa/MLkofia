# %% [markdown]
# <a href="https://colab.research.google.com/github/pythonpdnp/MS_kofia/blob/main/02_LinearRegMulti.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multiple Linear Regression

# %% [markdown]
# ### 데이터 입력 및 전처리

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/ML_kofia2024/homepricesM.csv")
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df.bedrooms.median()
# Out:
# 4.0

# %%
df.bedrooms = df.bedrooms.fillna(df.bedrooms.median())
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %% [markdown]
# ### 회귀분석 및 예측

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()

X = df.drop('price', axis='columns')
y = df.price

reg.fit(X, y)
# Out:
# LinearRegression()

# %%
reg.coef_, reg.intercept_
# Out:
# (array([  112.06244194, 23388.88007794, -3231.71790863]), 221323.00186540396)

# %% [markdown]
# *Find price of home with 3000 sqr ft area, 3 bedrooms, 40 year old*

# %%
reg.predict([[3000, 3, 40]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([498408.25158031])

# %%
112.06244194*3000 + 23388.88007794*3 + -3231.71790863*40 + 221323.00186540396
# Out:
# 498408.251574024
