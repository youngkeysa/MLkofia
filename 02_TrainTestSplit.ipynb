# %% [markdown]
# <a href="https://colab.research.google.com/github/pythonpdnp/MS_kofia/blob/main/02_TrainTestSplit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Training And Testing Available Data

# %% [markdown]
# ### 데이터 입력 및 전처리

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/ML_kofia2024/carprices.csv")

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Mileage'], df['Sell Price($)'])

# %%
plt.scatter(df['Age(yrs)'], df['Sell Price($)'])

# %%
X = df[['Mileage', 'Age(yrs)']]
y = df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train.shape , X_test.shape
# Out:
# ((14, 2), (6, 2))

# %% [markdown]
# ### 데이타 훈련, 테스트

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 4     46000         4
# 10    83000         7
# 3     22500         2
# 6     52000         5
# 16    28000         2
# 5     59000         5

# %%
reg.predict(X_test)
# Out:
# array([29563.01348296, 16278.38616086, 38100.17499994, 26867.9121634 ,
#        36595.10771053, 24952.37197688])

# %%
y_test
# Out:
# 4     31500
# 10    18700
# 3     40000
# 6     32000
# 16    35500
# 5     26750
# Name: Sell Price($), dtype: int64

# %%
reg.score(X_train, y_train)
# Out:
# 0.936182581351481

# %%
reg.score(X_test, y_test)
# Out:
# 0.8379289714283311
